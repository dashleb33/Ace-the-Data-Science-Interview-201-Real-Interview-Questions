# %% [markdown]
# <a href="https://colab.research.google.com/github/hansglick/book_errata/blob/main/p029_NLP_Metrics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q "tensorflow-text==2.8.*"
# Out:
#      |████████████████████████████████| 4.9 MB 6.8 MB/s

# %%
import tensorflow as tf
import tensorflow_text as text
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# # Les métriques NLP
#
# Il existe des tonnes de métriques destinées à évaluer la qualité d'une prédiction d'un texte, on en voit deux :
#  * ROUGE-L score
#  * BLEU score

# %% [markdown]
# # ROUGLE-L

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ____
#
# # BLEU

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data

# %%
# hypothèses représente les prédictions
hypotheses = tf.ragged.constant([['captain', 'of', 'the', 'delta', 'flight'],
                                 ['the', '1990', 'transcript']])
# references représente les experts
references = tf.ragged.constant([['delta', 'air', 'lines', 'flight'],
                                 ['this', 'concludes', 'the', 'transcript']])

# ROUGE-L
result = text.metrics.rouge_l(hypotheses, references)
print('F-Measure: %s' % result.f_measure)
print('P-Measure: %s' % result.p_measure)
print('R-Measure: %s' % result.r_measure)

# ROUGE-L avec alpha
# alpha proche de 0 -> plus d'importance sur le Recall
# alpha proche de 1 -> plus d'importance sur la Précision
# alpha à 0.5 -> poids égal sur Recall/Precision
# Compute ROUGE-L with alpha=0
result = text.metrics.rouge_l(hypotheses, references, alpha=0)
print('F-Measure (alpha=0): %s' % result.f_measure)
print('P-Measure (alpha=0): %s' % result.p_measure)
print('R-Measure (alpha=0): %s' % result.r_measure)

# Compute ROUGE-L with alpha=1
result = text.metrics.rouge_l(hypotheses, references, alpha=1)
print('F-Measure (alpha=1): %s' % result.f_measure)
print('P-Measure (alpha=1): %s' % result.p_measure)
print('R-Measure (alpha=1): %s' % result.r_measure)
# Out:
# F-Measure: tf.Tensor([0.44444448 0.57142854], shape=(2,), dtype=float32)
# P-Measure: tf.Tensor([0.4       0.6666667], shape=(2,), dtype=float32)
# R-Measure: tf.Tensor([0.5 0.5], shape=(2,), dtype=float32)

# %% [markdown]
# # Weighted HArmonic Mean formula

# %% [markdown]
# ![image.png](data:image/png;base64,...)
