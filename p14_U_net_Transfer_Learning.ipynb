# %% [markdown]
# <a href="https://colab.research.google.com/github/hansglick/book_errata/blob/main/p14_U_net_Transfer_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# # Objectif
#  * Entraîner un modèle U-Net avec un pretrained model MobileNet sur les données Oxford III dataset
#
# ### Tips
#  * Télécharger les données : `dataset, info = tfds.load('oxford_iiit_pet:3.*.*', with_info=True)`
#  * Préprocesser les images, valeur des pixels entre 0 et 1
#  * Un label est une matrice de taille égale à l'input avec les valeurs 1,2,3. 3 correspond au contenu. 2 Correspond au contour. 1 correspond à du vide
#  * Taille de l'input : Tensor 128,128,3
#  * Appliquer un layer d'augmentation via une map methode via `tf.keras.layers.RandomFlip(mode="horizontal", seed=seed)`
#  * Vérifier les données en affichant au hasard quelques paires input,label
#  * Utilisez une librairie disponible sur github avec : `pip install git+https://github.com/tensorflow/examples.git` puis `from tensorflow_examples.models.pix2pix import pix2pix`
#  * Utilisez la loss `tf.keras.losses.SparseCategoricalCrossentropy`
#  * Créez une fonction pour afficher le masque prédit
#  * Creéz un callback qui permet de suivre la progression de l'apprentissage
#  * Ne pas faire de custom loop, utilisez .compile() et .fit()
#  * Pousser le délire en modifiant la loss pr mettre plus de poids sur les classes de pixels les moins fréquents 1 et 2. (1,2) ,(2,2) , (3,1)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
